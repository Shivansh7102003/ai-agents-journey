# %%
from tensorflow.keras.layers import Dense , Conv2D, Flatten , AveragePooling2D
from keras import Sequential
from keras.datasets import mnist

# %%
(x_train , y_train) , (x_test , y_test) = mnist.load_data()

# %%
model = Sequential()

model.add(Conv2D(6,kernel_size = (5,5) , padding = "valid" , activation = "tanh" , input_shape = (28,28,1)))
model.add(AveragePooling2D(pool_size = (2,2),strides = 2 , padding = "valid"))

model.add(Conv2D(16,kernel_size = (5,5) , padding = "valid" , activation = "tanh"))
model.add(AveragePooling2D(pool_size= (2,2) , strides = 2 , padding = "valid"))

model.add(Flatten())
model.add(Dense(120 , activation = "tanh"))
model.add(Dense(84 , activation = "tanh"))
model.add(Dense(10 , activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 24, 24, 6)         156
#
#  average_pooling2d_4 (Avera  (None, 12, 12, 6)         0
#  gePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 16)          2416
#
#  average_pooling2d_5 (Avera  (None, 4, 4, 16)          0
#  gePooling2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 120)               30840
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44426 (173.54 KB)
# Trainable params: 44426 (173.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = "sparse_categorical_crossentropy" , optimizer = 'adam' , metrics = 'accuracy')

# %%
history = model.fit(x_train , y_train , epochs = 5 , validation_data= (x_test , y_test))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1604 - accuracy: 0.9524 - val_loss: 0.0685 - val_accuracy: 0.9794
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0679 - accuracy: 0.9790 - val_loss: 0.0517 - val_accuracy: 0.9837
# Epoch 3/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0515 - accuracy: 0.9841 - val_loss: 0.0436 - val_accuracy: 0.9858
# Epoch 4/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0424 - accuracy: 0.9868 - val_loss: 0.0414 - val_accuracy: 0.9862
# Epoch 5/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0444 - val_accuracy: 0.9864
# Epoch 6/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0299 - accuracy: 0.9902 - val_loss: 0.0494 - val_accuracy: 0.9833
# Epoch 7/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0295 - accuracy: 0.9908 - val_loss: 0.0372 - val_accuracy: 0.9881
# Epoch 8/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0229 - accuracy: 0.9923 - val_loss: 0.0377 - val_accuracy: 0.9882
# Epoch 9/50
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.0438 - val_accuracy: 0.9860
# Epoch 10/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.0463 - val_accuracy: 0.9868
# Epoch 11/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0451 - val_accuracy: 0.9869
# Epoch 12/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0468 - val_accuracy: 0.9852
# Epoch 13/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0412 - val_accuracy: 0.9876
# Epoch 14/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0412 - val_accuracy: 0.9873
# Epoch 15/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0417 - val_accuracy: 0.9872
# Epoch 16/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0391 - val_accuracy: 0.9880
# Epoch 17/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0509 - val_accuracy: 0.9859
# Epoch 18/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.0425 - val_accuracy: 0.9878
# Epoch 19/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0439 - val_accuracy: 0.9879
# Epoch 20/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0443 - val_accuracy: 0.9873
# Epoch 21/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.0506 - val_accuracy: 0.9871
# Epoch 22/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0616 - val_accuracy: 0.9833
# Epoch 23/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0446 - val_accuracy: 0.9874
# Epoch 24/50
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0525 - val_accuracy: 0.9862
# Epoch 25/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0523 - val_accuracy: 0.9864
# Epoch 26/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0476 - val_accuracy: 0.9877
# Epoch 27/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.0444 - val_accuracy: 0.9879
# Epoch 28/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0447 - val_accuracy: 0.9888
# Epoch 29/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0528 - val_accuracy: 0.9870
# Epoch 30/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.0430 - val_accuracy: 0.9884
# Epoch 31/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0547 - val_accuracy: 0.9869
# Epoch 32/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0600 - val_accuracy: 0.9855
# Epoch 33/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0572 - val_accuracy: 0.9860
# Epoch 34/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0552 - val_accuracy: 0.9882
# Epoch 35/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0481 - val_accuracy: 0.9881
# Epoch 36/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0531 - val_accuracy: 0.9875
# Epoch 37/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0570 - val_accuracy: 0.9863
# Epoch 38/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0547 - val_accuracy: 0.9877
# Epoch 39/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0610 - val_accuracy: 0.9845
# Epoch 40/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0547 - val_accuracy: 0.9866
# Epoch 41/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0555 - val_accuracy: 0.9869
# Epoch 42/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0551 - val_accuracy: 0.9876
# Epoch 43/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0568 - val_accuracy: 0.9864
# Epoch 44/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0653 - val_accuracy: 0.9859
# Epoch 45/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0541 - val_accuracy: 0.9881
# Epoch 46/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0627 - val_accuracy: 0.9859
# Epoch 47/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0555 - val_accuracy: 0.9872
# Epoch 48/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0652 - val_accuracy: 0.9863
# Epoch 49/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0554 - val_accuracy: 0.9878
# Epoch 50/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0482 - val_accuracy: 0.9896
