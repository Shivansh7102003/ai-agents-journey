# %%
import numpy as np 
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns = ["cgpa","profile_score" , "lpa"])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
    np.random.seed(3)
    parameters = {}
    L = len(layer_dims)

    for l in range(1,L):
        parameters["W" +str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
        parameters["b"+ str(l)] = np.zeros((layer_dims[l],1))

    return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev , W,b):
    z = np.dot(W.T ,A_prev)+b
    return z

# %% [markdown]
# # forward propgation

# %%
def L_layer_forward(X,parameters):
    A=X
    L=len(parameters)//2 #numbers of layers in neural network

    for l in range(1 , L+1):
        A_prev = A
        W1 = parameters["W"+str(l)]
        b1 = parameters["b" +str(l)]
        print("A"+str(l-1)+":" ,A_prev)
        print("W" + str(l) +":", W1)
        print("b"+str(l)+":",b1)
        print("--"*20)

        A= linear_forward(A_prev , W1,b1)
        print("A"+str(l)+":" , A)
        print("**"*20)

    return A,A_prev

# %%
X= df[["cgpa","profile_score"]].values[0].reshape(2,1) # shape (no of features , no of training example)
y = df[["lpa"]].values[0][0]
parameters = initialize_parameters([2,2,1])

# %%
y_hat , A1 =L_layer_forward(X,parameters)
# Out:
# A0: [[8]
#  [8]]
# W1: [[0.1 0.1]
#  [0.1 0.1]]
# b1: [[0.]
#  [0.]]
# ----------------------------------------
# A1: [[1.6]
#  [1.6]]
# ****************************************
# A1: [[1.6]
#  [1.6]]
# W2: [[0.1]
#  [0.1]]
# b2: [[0.]]
# ----------------------------------------
# A2: [[0.32]]
# ****************************************

# %%
y_hat = y_hat[0][0]
y_hat
# Out:
# 0.32000000000000006

# %%
def update_parameters(parameters , y, y_hat , A1 , X):
    parameters['W2'][0][0] =parameters['W2'][0][0] + (.001*2*(y-y_hat)*A1[0][0])
    parameters['W2'][1][0] =parameters['W2'][1][0] + (.001*2*(y-y_hat)*A1[1][0])
    parameters['b2'][0][0] =parameters['W2'][1][0] + (.001*2*(y-y_hat))
    
    parameters['W1'][0][0] =parameters['W1'][0][0] + (.001*2*(y-y_hat)*parameters["W2"][0][0]*X[0][0])
    parameters['W1'][0][1] =parameters['W1'][0][1] + (.001*2*(y-y_hat)*parameters["W2"][0][0]*X[1][0])
    parameters['b1'][0][0] =parameters['b1'][0][0] + (.001*2*(y-y_hat)*parameters["W2"][0][0])
    
    parameters['W1'][1][0] =parameters['W1'][1][0] + (.001*2*(y-y_hat)*parameters["W2"][1][0]*X[0][0])
    parameters['W1'][1][1] =parameters['W1'][1][1] + (.001*2*(y-y_hat)*parameters["W2"][1][0]*X[1][0])
    parameters['b1'][1][0] =parameters['b1'][1][0] + (.001*2*(y-y_hat)*parameters["W2"][1][0])

# %%
update_parameters(parameters , y,y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
epochs = 100
parameters = initialize_parameters([2,2,1])
for i in range(epochs):
    
    loss = []
    
    for j in range(df.shape[0]):
        x = df[["cgpa" , "profile_score"]].values[j].reshape(2,1)
        y = df[["lpa"]].values[j][0]

# parameter initialixzation

        y_hat , A1 = L_layer_forward(x , parameters)
        y_hat = y_hat[0][0]
        update_parameters(parameters,y,y_hat,A1,x)

        loss.append((y-y_hat)**2)
    print('epoch -',i+1 ,"loss" , np.array(loss).mean())

parameters
# Out:
# A0: [[8]
#  [8]]
# W1: [[0.1 0.1]
#  [0.1 0.1]]
# b1: [[0.]
#  [0.]]
# ----------------------------------------
# A1: [[1.6]
#  [1.6]]
# ****************************************
# A1: [[1.6]
#  [1.6]]
# W2: [[0.1]
#  [0.1]]
# b2: [[0.]]
# ----------------------------------------
# A2: [[0.32]]
# ****************************************
# A0: [[7]
#  [9]]
# W1: [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1: [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1: [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1: [[1.70612461]
#  [1.70612461]]
# W2: [[0.111776]
#  [0.111776]]
# b2: [[0.119136]]
# ----------------------------------------
# A2: [[0.50054357]]
# ****************************************
# A0: [[ 6]
#  [10]]
# W1: [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1: [[0.0019667]
#  [0.0019667]]
# ----------------------------------------
# A1: [[1.83539945]
#  [1.87200826]]
# ...

# %%
import tensorflow
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential()
model.add(Dense(2,activation = "linear" , input_dim = 2))
model.add(Dense(1 , activation = "linear"))
# Out:
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = "mean_squared_error" ,optimizer = "adam" )
# Out:
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
model.fit(df.iloc[:,0:-1].values , df.lpa.values ,epochs = 75 , verbose = 1 , batch_size =  1)
# Out:
# Epoch 1/75
# WARNING:tensorflow:From C:\Users\shiva\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4/4 [==============================] - 1s 5ms/step - loss: 12.9420
# Epoch 2/75
# 4/4 [==============================] - 0s 3ms/step - loss: 12.2219
# Epoch 3/75
# 4/4 [==============================] - 0s 2ms/step - loss: 11.5787
# Epoch 4/75
# 4/4 [==============================] - 0s 1ms/step - loss: 10.9481
# Epoch 5/75
# 4/4 [==============================] - 0s 2ms/step - loss: 10.1977
# Epoch 6/75
# 4/4 [==============================] - 0s 3ms/step - loss: 9.6796
# Epoch 7/75
# 4/4 [==============================] - 0s 3ms/step - loss: 9.0156
# Epoch 8/75
# 4/4 [==============================] - 0s 3ms/step - loss: 8.5145
# Epoch 9/75
# 4/4 [==============================] - 0s 3ms/step - loss: 8.0733
# Epoch 10/75
# ...
